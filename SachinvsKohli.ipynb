# %%
#Find the current working directory in Python
import os
os.getcwd()
# Out:
# 'G:\\data analytics dataset\\sportsanalytics\\Datasets'

# %%
os.chdir("G:\\data analytics dataset\\sportsanalytics\\Datasets")

# %%
import pandas as pd

# %%
df=pd.read_csv('Kohli vs Sachin/ODI_data.csv')

# %%
df.head()
# Out:
#   Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 0        E Lewis                  65                      65
# 1       N Pooran                  42                      42
# 2     SO Hetmyer                  18                      18
# 3       RL Chase                  18                      18
# 4    SS Cottrell                  17                      17
#
#   Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 0                    128                  1.0                   0.0
# 1                     69                  1.0                   0.0
# 2                     31                  1.0                   0.0
# 3                     34                  1.0                   0.0
# 4                     23                  1.0                   0.0
#
#   Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# 0                  80                      8                      1
# ...

# %%
len(df)
# Out:
# 171968

# %%
df.size
# Out:
# 4815104

# %%
df.shape
# Out:
# (171968, 28)

# %%
df.columns
# Out:
# Index(['Innings Player', 'Innings Runs Scored', 'Innings Runs Scored Num',
#        'Innings Minutes Batted', 'Innings Batted Flag', 'Innings Not Out Flag',
#        'Innings Balls Faced', 'Innings Boundary Fours',
#        'Innings Boundary Sixes', 'Innings Batting Strike Rate',
#        'Innings Number', 'Opposition', 'Ground', 'Innings Date', 'Country',
#        '50's', '100's', 'Innings Runs Scored Buckets', 'Innings Overs Bowled',
#        'Innings Bowled Flag', 'Innings Maidens Bowled',
#        'Innings Runs Conceded', 'Innings Wickets Taken', '4 Wickets',
#        '5 Wickets', '10 Wickets', 'Innings Wickets Taken Buckets',
#        'Innings Economy Rate'],
#       dtype='object')

# %%
#Innings scored num
#Strike Rate
#100's
#50's
#Team contribution

# %%
df['Innings Runs Scored Num'].unique()
# Out:
# array(['65', '42', '18', '17', '13', '11', '5', '0', '120', '71', '20',
#        '16', '3', '2', '1', '-', nan, '40', '6', '4', '87', '54', '46',
#        '30', '12', '69', '39', '14', '10', '9', '8', '7', '82', '52',
#        '41', '15', '98', '43', '19', '111', '48', '36', '25', '67', '60',
#        '84', '59', '55', '47', '85', '49', '45', '34', '29', '22', '74',
#        '28', '77', '50', '32', '23', '35', '122', '100', '95', '103',
#        '113', '53', '96', '27', '64', '58', '33', '31', '73', '56', '86',
#        '62', '106', '24', '57', '104', '26', '66', '51', '118', '105',
#        '101', '21', '79', '44', '102', '88', '80', '72', '97', '68', '89',
#        '38', '83', '63', '148', '166', '90', '76', '37', '70', '124',
#        '94', '140', '153', '107', '117', '121', '92', '78', '75', '114',
#        '115', '130', '128', '151', '110', '138', '135', '109', '61',
#        '179', '170', '112', '116', '91', '143', '93', '123', '145', '81',
# ...

# %%
df.dropna(subset=['Innings Runs Scored Num'])
# Out:
#        Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 0             E Lewis                  65                      65
# 1            N Pooran                  42                      42
# 2          SO Hetmyer                  18                      18
# 3            RL Chase                  18                      18
# 4         SS Cottrell                  17                      17
# ...               ...                 ...                     ...
# 171941       RW Marsh                 10*                      10
# 171942    GD McKenzie                 DNB                       -
# 171943     AA Mallett                 DNB                       -
# 171944    AN Connolly                 DNB                       -
# 171945     AL Thomson                 DNB                       -
#
#        Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 0                         128                  1.0                   0.0
# ...

# %%
df['Innings Runs Scored Num'].unique()
# Out:
# array(['65', '42', '18', '17', '13', '11', '5', '0', '120', '71', '20',
#        '16', '3', '2', '1', '-', nan, '40', '6', '4', '87', '54', '46',
#        '30', '12', '69', '39', '14', '10', '9', '8', '7', '82', '52',
#        '41', '15', '98', '43', '19', '111', '48', '36', '25', '67', '60',
#        '84', '59', '55', '47', '85', '49', '45', '34', '29', '22', '74',
#        '28', '77', '50', '32', '23', '35', '122', '100', '95', '103',
#        '113', '53', '96', '27', '64', '58', '33', '31', '73', '56', '86',
#        '62', '106', '24', '57', '104', '26', '66', '51', '118', '105',
#        '101', '21', '79', '44', '102', '88', '80', '72', '97', '68', '89',
#        '38', '83', '63', '148', '166', '90', '76', '37', '70', '124',
#        '94', '140', '153', '107', '117', '121', '92', '78', '75', '114',
#        '115', '130', '128', '151', '110', '138', '135', '109', '61',
#        '179', '170', '112', '116', '91', '143', '93', '123', '145', '81',
# ...

# %%
df.dropna(subset=['Innings Runs Scored Num'],inplace = True)

# %%
df['Innings Runs Scored Num'].unique()
# Out:
# array(['65', '42', '18', '17', '13', '11', '5', '0', '120', '71', '20',
#        '16', '3', '2', '1', '-', '40', '6', '4', '87', '54', '46', '30',
#        '12', '69', '39', '14', '10', '9', '8', '7', '82', '52', '41',
#        '15', '98', '43', '19', '111', '48', '36', '25', '67', '60', '84',
#        '59', '55', '47', '85', '49', '45', '34', '29', '22', '74', '28',
#        '77', '50', '32', '23', '35', '122', '100', '95', '103', '113',
#        '53', '96', '27', '64', '58', '33', '31', '73', '56', '86', '62',
#        '106', '24', '57', '104', '26', '66', '51', '118', '105', '101',
#        '21', '79', '44', '102', '88', '80', '72', '97', '68', '89', '38',
#        '83', '63', '148', '166', '90', '76', '37', '70', '124', '94',
#        '140', '153', '107', '117', '121', '92', '78', '75', '114', '115',
#        '130', '128', '151', '110', '138', '135', '109', '61', '179',
#        '170', '112', '116', '91', '143', '93', '123', '145', '81', '150',
# ...

# %%
df=df[df['Innings Runs Scored Num']!='-']

# %%
df['Innings Runs Scored Num'].unique()
# Out:
# array(['65', '42', '18', '17', '13', '11', '5', '0', '120', '71', '20',
#        '16', '3', '2', '1', '40', '6', '4', '87', '54', '46', '30', '12',
#        '69', '39', '14', '10', '9', '8', '7', '82', '52', '41', '15',
#        '98', '43', '19', '111', '48', '36', '25', '67', '60', '84', '59',
#        '55', '47', '85', '49', '45', '34', '29', '22', '74', '28', '77',
#        '50', '32', '23', '35', '122', '100', '95', '103', '113', '53',
#        '96', '27', '64', '58', '33', '31', '73', '56', '86', '62', '106',
#        '24', '57', '104', '26', '66', '51', '118', '105', '101', '21',
#        '79', '44', '102', '88', '80', '72', '97', '68', '89', '38', '83',
#        '63', '148', '166', '90', '76', '37', '70', '124', '94', '140',
#        '153', '107', '117', '121', '92', '78', '75', '114', '115', '130',
#        '128', '151', '110', '138', '135', '109', '61', '179', '170',
#        '112', '116', '91', '143', '93', '123', '145', '81', '150', '162',
# ...

# %%
import warnings
warnings.filterwarnings("ignore")
df['Innings Date'] = pd.to_datetime(df['Innings Date'])

# %%
df['Innings Year']= df['Innings Date'].dt.year

# %%
df.head()
# Out:
#   Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 0        E Lewis                  65                      65
# 1       N Pooran                  42                      42
# 2     SO Hetmyer                  18                      18
# 3       RL Chase                  18                      18
# 4    SS Cottrell                  17                      17
#
#   Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 0                    128                  1.0                   0.0
# 1                     69                  1.0                   0.0
# 2                     31                  1.0                   0.0
# 3                     34                  1.0                   0.0
# 4                     23                  1.0                   0.0
#
#   Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# 0                  80                      8                      1
# ...

# %%
df['Innings Year']
# Out:
# 0         2019
# 1         2019
# 2         2019
# 3         2019
# 4         2019
#           ...
# 171937    1971
# 171938    1971
# 171939    1971
# 171940    1971
# 171941    1971
# Name: Innings Year, Length: 67595, dtype: int64

# %%
len(df)
# Out:
# 67595

# %%
df.shape
# Out:
# (67595, 29)

# %%
df.columns
# Out:
# Index(['Innings Player', 'Innings Runs Scored', 'Innings Runs Scored Num',
#        'Innings Minutes Batted', 'Innings Batted Flag', 'Innings Not Out Flag',
#        'Innings Balls Faced', 'Innings Boundary Fours',
#        'Innings Boundary Sixes', 'Innings Batting Strike Rate',
#        'Innings Number', 'Opposition', 'Ground', 'Innings Date', 'Country',
#        '50's', '100's', 'Innings Runs Scored Buckets', 'Innings Overs Bowled',
#        'Innings Bowled Flag', 'Innings Maidens Bowled',
#        'Innings Runs Conceded', 'Innings Wickets Taken', '4 Wickets',
#        '5 Wickets', '10 Wickets', 'Innings Wickets Taken Buckets',
#        'Innings Economy Rate', 'Innings Year'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace("'"," ")

# %%
df.columns
# Out:
# Index(['Innings Player', 'Innings Runs Scored', 'Innings Runs Scored Num',
#        'Innings Minutes Batted', 'Innings Batted Flag', 'Innings Not Out Flag',
#        'Innings Balls Faced', 'Innings Boundary Fours',
#        'Innings Boundary Sixes', 'Innings Batting Strike Rate',
#        'Innings Number', 'Opposition', 'Ground', 'Innings Date', 'Country',
#        '50 s', '100 s', 'Innings Runs Scored Buckets', 'Innings Overs Bowled',
#        'Innings Bowled Flag', 'Innings Maidens Bowled',
#        'Innings Runs Conceded', 'Innings Wickets Taken', '4 Wickets',
#        '5 Wickets', '10 Wickets', 'Innings Wickets Taken Buckets',
#        'Innings Economy Rate', 'Innings Year'],
#       dtype='object')

# %%
df[ (df['Innings Player'] == 'V Kohli') & (df['100 s']==1) ]
# Out:
#       Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 11           V Kohli                 120                     120
# 3619         V Kohli                 123                     123
# 3751         V Kohli                 116                     116
# 4851         V Kohli                 104                     104
# 5555         V Kohli                 107                     107
# 5643         V Kohli                157*                     157
# 5776         V Kohli                 140                     140
# 8613         V Kohli                129*                     129
# 8921         V Kohli                160*                     160
# 9009         V Kohli                 112                     112
# 10286        V Kohli                 113                     113
# 10428        V Kohli                 121                     121
# 11198        V Kohli                110*                     110
# ...

# %%
df[ (df['Innings Player'] == 'SR Tendulkar') & (df['100 s']==1) ]
# Out:
#        Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 37334    SR Tendulkar                 114                     114
# 42735    SR Tendulkar                 111                     111
# 43351    SR Tendulkar                 120                     120
# 48939    SR Tendulkar                200*                     200
# 50523    SR Tendulkar                 175                     175
# 51898    SR Tendulkar                 138                     138
# 54131    SR Tendulkar                163*                     163
# 59213    SR Tendulkar                117*                     117
# 66231    SR Tendulkar                100*                     100
# 68959    SR Tendulkar                141*                     141
# 72292    SR Tendulkar                 100                     100
# 76070    SR Tendulkar                 123                     123
# 81306    SR Tendulkar                 141                     141
# ...

# %%
df['Innings Runs Scored Num'] = df['Innings Runs Scored Num'].astype(int)

# %%
df['Innings Not Out Flag'] = df['Innings Not Out Flag'].astype(int)

# %%
df['Innings Balls Faced'] = df['Innings Balls Faced'].astype(int)

# %%
sachin_df = df[(df['Innings Year'] >= 1994) & (df['Innings Year'] <= 2004) ]

# %%
Kohli_df = df[(df['Innings Year'] >= 2009) & (df['Innings Year'] <= 2019) ]

# %%
df.dtypes
# Out:
# Innings Player                           object
# Innings Runs Scored                      object
# Innings Runs Scored Num                   int32
# Innings Minutes Batted                   object
# Innings Batted Flag                     float64
# Innings Not Out Flag                      int32
# Innings Balls Faced                       int32
# Innings Boundary Fours                   object
# Innings Boundary Sixes                   object
# Innings Batting Strike Rate              object
# Innings Number                           object
# Opposition                               object
# Ground                                   object
# Innings Date                     datetime64[ns]
# Country                                  object
# 50 s                                    float64
# 100 s                                   float64
# Innings Runs Scored Buckets              object
# Innings Overs Bowled                     object
# Innings Bowled Flag                     float64
# ...

# %%
#Total runs scored

# %%
sdf= sachin_df[sachin_df['Innings Player'] == 'SR Tendulkar']

# %%
vdf= Kohli_df[Kohli_df['Innings Player'] == 'V Kohli']

# %%
sdf_runs = sum(sdf['Innings Runs Scored Num'])
vdf_runs = sum(vdf['Innings Runs Scored Num'])
print(sdf_runs, vdf_runs)
# Out:
# 11818 11247

# %%
sdf_runs_per_innings = sum(sdf['Innings Runs Scored Num'])/ len(sdf)

# %%
vdf_runs_per_innings = sum(vdf['Innings Runs Scored Num'])/ len(vdf)

# %%
print (sdf_runs_per_innings,vdf_runs_per_innings )
# Out:
# 43.608856088560884 50.20982142857143

# %%
sdf_strike_rate = 100*sum(sdf['Innings Runs Scored Num'])/sum(sdf['Innings Balls Faced'])

# %%
vdf_strike_rate = 100*sum(vdf['Innings Runs Scored Num'])/sum(vdf['Innings Balls Faced'])

# %%
print (sdf_strike_rate,vdf_strike_rate)
# Out:
# 88.21377920429947 93.56126778138258

# %%
print (sum(sdf['100 s']), sum(vdf['100 s']))
# Out:
# 37.0 42.0

# %%
print (sum(sdf['50 s']), sum(vdf['50 s']))
# Out:
# 57.0 53.0

# %%
Team_contri_during_Sachin_df = sachin_df[sachin_df['Country']== 'India']

# %%
Team_runs_during_Sachin = sum(Team_contri_during_Sachin_df['Innings Runs Scored Num'])

# %%
Team_contri_during_Kohli_df = Kohli_df[Kohli_df['Country']== 'India']

# %%
Team_runs_during_Kohli = sum(Team_contri_during_Kohli_df['Innings Runs Scored Num'])

# %%
print (Team_runs_during_Sachin,Team_runs_during_Kohli )
# Out:
# 69715 63867

# %%
Sachin_contri_per = 100*sdf_runs/Team_runs_during_Sachin

# %%
Kohli_contri_per = 100*vdf_runs/Team_runs_during_Kohli

# %%
print (Sachin_contri_per, Kohli_contri_per)
# Out:
# 16.951875493078965 17.610033350556627

# %%
Sachin_group_players_df=sachin_df.groupby(by=['Innings Player']).sum()

# %%
Sachin_group_players_df.dtypes
# Out:
# Innings Runs Scored Num      int32
# Innings Batted Flag        float64
# Innings Not Out Flag         int32
# Innings Balls Faced          int32
# 50 s                       float64
# 100 s                      float64
# Innings Bowled Flag        float64
# 4 Wickets                  float64
# 5 Wickets                  float64
# 10 Wickets                 float64
# Innings Year                 int64
# dtype: object

# %%
Sachin_group_players_df.sort_values(by=['Innings Runs Scored Num'],ascending=False)
# Out:
#                 Innings Runs Scored Num  Innings Batted Flag  \
# Innings Player
# SR Tendulkar                      11818                271.0
# SC Ganguly                         9911                256.0
# ST Jayasuriya                      9297                280.0
# Inzamam-ul-Haq                     8561                254.0
# R Dravid                           7751                224.0
# ...                                 ...                  ...
# Rafiqul Islam                         0                  1.0
# SD Anurasiri                          0                  1.0
# Shadab Kabir                          0                  3.0
# V Yadav                               0                  1.0
# Zakir Hossain                         0                  1.0
#
#                 Innings Not Out Flag  Innings Balls Faced  50 s  100 s  \
# Innings Player
# SR Tendulkar                      24                13397  57.0   37.0
# ...

# %%
from matplotlib import pyplot as plt
Sachin_group_players_df['Innings Runs Scored Num'].sort_values(ascending=False).head(10).plot(kind='barh')
plt.show()

# %%
Kohli_group_players_df=Kohli_df.groupby(by=['Innings Player']).sum()

# %%
from matplotlib import pyplot as plt
Kohli_group_players_df['Innings Runs Scored Num'].sort_values(ascending=False).head(10).plot(kind='barh')
plt.show()

# %%
sdf.groupby('Innings Year').sum()['Innings Runs Scored Num'].plot(kind = 'bar')
plt.show()

# %%
vdf.groupby('Innings Year').sum()['Innings Runs Scored Num'].plot(kind = 'bar')
plt.show()

# %%
#player runs excluding sachin
ex_sac_df = sachin_df[sachin_df['Innings Player'] != 'SR Tendulkar']
RPI_ex_sac_df = ex_sac_df['Innings Runs Scored Num'].sum()/len(ex_sac_df)

# %%
#player runs excluding kohli
ex_kohli_df = Kohli_df[Kohli_df['Innings Player'] != 'V Kohli']
RPI_ex_kohli_df = ex_kohli_df['Innings Runs Scored Num'].sum()/len(ex_kohli_df)

# %%
#Sachin vs Rest RPI
Sachin_vs_Rest_RPI = sdf_runs_per_innings/RPI_ex_sac_df

# %%
#Kohli vs Rest RPI
Kohli_vs_Rest_RPI = vdf_runs_per_innings/RPI_ex_kohli_df

# %%
print(Sachin_vs_Rest_RPI,Kohli_vs_Rest_RPI )
# Out:
# 1.9437755485945407 2.029683688052565

# %%
#Sachin vs Rest Strike Rate
SR_ex_sac = 100*ex_sac_df['Innings Runs Scored Num'].sum() / ex_sac_df['Innings Balls Faced'].sum()
Sachin_vs_Rest_SR = sdf_strike_rate/SR_ex_sac

# %%
#Kohli vs Rest Strike Rate
SR_ex_kohli = 100*ex_kohli_df['Innings Runs Scored Num'].sum() / ex_kohli_df['Innings Balls Faced'].sum()
Kohli_vs_Rest_SR = vdf_strike_rate/SR_ex_kohli

# %%
print (SR_ex_sac, SR_ex_kohli)
print (sdf_strike_rate, vdf_strike_rate)
print (Sachin_vs_Rest_SR , Kohli_vs_Rest_SR)
# Out:
# 72.33808936558636 83.42743413330612
# 88.21377920429947 93.56126778138258
# 1.2194651528391862 1.121468839996732

# %%
# Sachin vs Rest (Matches per 100)

Sachin_mat_per_100= len(sdf)/ sum(sdf['100 s'])
Rest_mat_per_100_sac = len(ex_sac_df)/sum(ex_sac_df['100 s'])
print (Sachin_mat_per_100,Rest_mat_per_100_sac)
# Out:
# 7.324324324324325 47.377969762419006

# %%
# Kohli vs Rest (Matches per 100)

Kohli_mat_per_100= len(vdf)/ sum(vdf['100 s'])
Rest_mat_per_100_kohli = len(ex_kohli_df)/sum(ex_kohli_df['100 s'])
print (Kohli_mat_per_100,Rest_mat_per_100_kohli)
# Out:
# 5.333333333333333 29.311827956989248
